# %%
# %pip install expt -q

# %%
open_colors = {
    "gray": {
        0: "#f8f9fa",
        1: "#f1f3f5",
        2: "#e9ecef",
        3: "#dee2e6",
        4: "#ced4da",
        5: "#adb5bd",
        6: "#868e96",
        7: "#495057",
        8: "#343a40",
        9: "#212529",
    },
    "red": {
        0: "#fff5f5",
        1: "#ffe3e3",
        2: "#ffc9c9",
        3: "#ffa8a8",
        4: "#ff8787",
        5: "#ff6b6b",
        6: "#fa5252",
        7: "#f03e3e",
        8: "#e03131",
        9: "#c92a2a",
    },
    "pink": {
        0: "#fff0f6",
        1: "#ffdeeb",
        2: "#fcc2d7",
        3: "#faa2c1",
        4: "#f783ac",
        5: "#f06595",
        6: "#e64980",
        7: "#d6336c",
        8: "#c2255c",
        9: "#a61e4d",
    },
    "grape": {
        0: "#f8f0fc",
        1: "#f3d9fa",
        2: "#eebefa",
        3: "#e599f7",
        4: "#da77f2",
        5: "#cc5de8",
        6: "#be4bdb",
        7: "#ae3ec9",
        8: "#9c36b5",
        9: "#862e9c",
    },
    "violet": {
        0: "#f3f0ff",
        1: "#e5dbff",
        2: "#d0bfff",
        3: "#b197fc",
        4: "#9775fa",
        5: "#845ef7",
        6: "#7950f2",
        7: "#7048e8",
        8: "#6741d9",
        9: "#5f3dc4",
    },
    "indigo": {
        0: "#edf2ff",
        1: "#dbe4ff",
        2: "#bac8ff",
        3: "#91a7ff",
        4: "#748ffc",
        5: "#5c7cfa",
        6: "#4c6ef5",
        7: "#4263eb",
        8: "#3b5bdb",
        9: "#364fc7",
    },
    "blue": {
        0: "#e7f5ff",
        1: "#d0ebff",
        2: "#a5d8ff",
        3: "#74c0fc",
        4: "#4dabf7",
        5: "#339af0",
        6: "#228be6",
        7: "#1c7ed6",
        8: "#1971c2",
        9: "#1864ab",
    },
    "cyan": {
        0: "#e3fafc",
        1: "#c5f6fa",
        2: "#99e9f2",
        3: "#66d9e8",
        4: "#3bc9db",
        5: "#22b8cf",
        6: "#15aabf",
        7: "#1098ad",
        8: "#0c8599",
        9: "#0b7285",
    },
    "teal": {
        0: "#e6fcf5",
        1: "#c3fae8",
        2: "#96f2d7",
        3: "#63e6be",
        4: "#38d9a9",
        5: "#20c997",
        6: "#12b886",
        7: "#0ca678",
        8: "#099268",
        9: "#087f5b",
    },
    "green": {
        0: "#ebfbee",
        1: "#d3f9d8",
        2: "#b2f2bb",
        3: "#8ce99a",
        4: "#69db7c",
        5: "#51cf66",
        6: "#40c057",
        7: "#37b24d",
        8: "#2f9e44",
        9: "#2b8a3e",
    },
    "lime": {
        0: "#f4fce3",
        1: "#e9fac8",
        2: "#d8f5a2",
        3: "#c0eb75",
        4: "#a9e34b",
        5: "#94d82d",
        6: "#82c91e",
        7: "#74b816",
        8: "#66a80f",
        9: "#5c940d",
    },
    "yellow": {
        0: "#fff9db",
        1: "#fff3bf",
        2: "#ffec99",
        3: "#ffe066",
        4: "#ffd43b",
        5: "#fcc419",
        6: "#fab005",
        7: "#f59f00",
        8: "#f08c00",
        9: "#e67700",
    },
    "orange": {
        0: "#fff4e6",
        1: "#ffe8cc",
        2: "#ffd8a8",
        3: "#ffc078",
        4: "#ffa94d",
        5: "#ff922b",
        6: "#fd7e14",
        7: "#f76707",
        8: "#e8590c",
        9: "#d9480f",
    },
}

# %%
import matplotlib.font_manager as font_manager
import glob

for font_path in glob.glob('../fonts/colfax/**'):
    font_manager.fontManager.addfont(font_path)
    prop = font_manager.FontProperties(fname=font_path)

# %%
import os
import glob
import pandas as pd
import numpy as np
import expt
import matplotlib.pyplot as plt
print("expt:", expt.__version__)
plt.rcParams['text.usetex'] = False
# Out:
# expt: 0.4.2

# %%
p = plt.rcParams

p["figure.figsize"] = 6, 3
p["figure.edgecolor"] = "white"
p["figure.facecolor"] = "white"

p["axes.linewidth"] = 0.8
# p["axes.facecolor"] = "#f5f8f8"
p["axes.edgecolor"] = "#ccccd6"
p["axes.ymargin"] = 0.1
p["axes.spines.bottom"] = True
p["axes.spines.left"] = True
p["axes.spines.right"] = False
p["axes.spines.top"] = False
p["axes.titleweight"] = "medium"
p["axes.titlecolor"] = "#424651"
p["axes.labelcolor"] = "#8A8A9D"
p["axes.titlepad"] = 10.0
p["font.family"] = ["Colfax"]

p["axes.grid"] = True
p["grid.color"] = "#E5E7EB"
p["grid.linewidth"] = 0.5

p["xtick.bottom"] = True
p["xtick.top"] = False
p["xtick.direction"] = "out"
p["xtick.major.size"] = 5
p["xtick.major.width"] = 0.5
p["xtick.minor.size"] = 3
p["xtick.minor.width"] = 0.5
p["xtick.minor.visible"] = False

p["ytick.left"] = True
p["ytick.right"] = False
p["ytick.direction"] = "out"
p["ytick.major.size"] = 5
p["ytick.major.width"] = 0.5
p["ytick.minor.size"] = 3
p["ytick.minor.width"] = 0.5
p["ytick.minor.visible"] = False

p["lines.linewidth"] = 1

# %%
# %cd MinigridSafeRL/
# !ls
# Out:
# [Errno 2] No such file or directory: 'MinigridSafeRL/'
# /teamspace/studios/this_studio/MinigridSafeRL
# README.md		    plotting.ipynb
# __pycache__		    qpriors
# buffers.py		    requirements.txt
# dqn_minigrid.py		    run_vae.sh
# dqn_minigrid_ae.py	    runs
# dqn_minigrid_ae_exp.py	    safeqnetwork.cleanrl_model
# dqn_minigrid_per.py	    scripts
# dqn_minigrid_safe.py	    t-SNE_789.pdf
# dqn_minigrid_safe_exp.py    train_ae_supervised.py
# dqn_minigrid_vae.py	    transferable_priors.py
# figures			    utils.py
# heatmap.pdf		    videos
# learn_pseudo_Q_minigrid.py  visualize_embeddings_ae.py
# main.py			    visualize_embeddings_vae.py
# plot.sh			    wandb
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
import wandb

api = wandb.Api()
entity, project = "kiendd-hrt", "minigrid-saferl-exp2"
runs = api.runs(entity + "/" + project)
run_names = [run.name for run in runs if "unused" not in run.tags]

# %%
# run_names = [
#     'MiniGrid-LavaCrossingS9N1-v0__dqn_minigrid_safe_exp__789__1720924066',
#     'MiniGrid-LavaCrossingS9N1-v0__dqn_minigrid_safe_exp__456__1720840008',
#     'MiniGrid-LavaCrossingS9N1-v0__dqn_minigrid_safe_exp__123__1720839474'
# ]
import shutil
for run_name in run_names:
    if os.path.exists(f'runs/expt/{run_name}'):
        continue
    if os.path.exists(f'runs/{run_name}'):
        shutil.copytree(f'runs/{run_name}', f'runs/expt/{run_name}')
    else:
        print(f"{run_name} not found")

# %%
runs = expt.get_runs(f"./runs/expt/**")
runs
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2024-10-28 09:38:40.053470: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-28 09:38:40.053500: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-28 09:38:40.053534: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
import re
algorithm_name = {
    'dqn_minigrid_safe_exp': 'DQN + Domain Priors + State Safety Check',
    'dqn_minigrid_per': 'DQN',
    'dqn_minigrid_vae': 'DQN + VAE',
    'dqn_minigrid_ae': 'DQN + Vanilla AE',
    'dqn_minigrid_safe': 'DQN + Domain Priors',
    'dqn_minigrid_safe_0.5': 'DQN + Domain Priors (0.5)'
}
def run_config(run):
    m = re.match(f"(?P<env_id>.*)__(?P<algorithm>.*)__(?P<seed>.*)__(?P<date>.*)", run.name)
    params = m.groupdict()   # {algorithm: ..., env_id: ..., seed: ...}
    params['algorithm'] = algorithm_name[params['algorithm']]
    params['env_id'] = params['env_id'].split('-')[1]
    # params.pop('seed')
    params.pop('date')
    # print(params)
    return params
rt = runs.to_dataframe(config_fn=run_config,
                       as_hypothesis=True, hypothesis_namer=lambda cfg, _: cfg['algorithm'])
rt
# Out:
#                                                                                                   hypothesis
# env_id           algorithm
# LavaCrossingS9N1 DQN                                       Hypothesis('DQN', 3 runs: [
#  Run('./runs/expt/...
#                  DQN + Domain Priors                       Hypothesis('DQN + Domain Priors', 3 runs: [
#  R...
#                  DQN + Domain Priors (0.5)                 Hypothesis('DQN + Domain Priors (0.5)', 3 runs...
#                  DQN + Domain Priors + State Safety Check  Hypothesis('DQN + Domain Priors + State Safety...
#                  DQN + VAE                                 Hypothesis('DQN + VAE', 3 runs: [
#  Run('./runs...
#                  DQN + Vanilla AE                          Hypothesis('DQN + Vanilla AE', 3 runs: [
#  Run(...
# LavaCrossingS9N2 DQN                                       Hypothesis('DQN', 3 runs: [
#  Run('./runs/expt/...
# ...

# %%
def open_colors_palette(colors=('blue', 'violet', 'red', 'yellow', 'green', 'orange', 'pink', 'cyan', 'teal'), level=6):
    return[open_colors[c][level] for c in colors]
from matplotlib import cycler
p['axes.prop_cycle'] = cycler('color', open_colors_palette(level=8))

# %%
from tqdm.auto import tqdm
from expt.plot import GridPlot

g = GridPlot(y_names=rt.reset_index().env_id.unique())

for env_id, t in tqdm(rt.groupby('env_id')):
    ex = expt.Experiment.from_dataframe(t, name=env_id)
    ex.plot(ax=g[env_id], title=env_id,
            x='global_step', y='charts/episodic_return',
            err_style='band', std_alpha=0.1,
            rolling=100, n_samples=2000, legend=False,
            tight_layout=False, figsize=(10, 6)
           )

# Put a legend on the last empty grid axes
g.add_legend(ax=g.axes[-1, -1], loc="upper left", bbox_to_anchor=(0, 1))

# Some post-processing with matplotlib API so that the plot looks nicer
for ax in g.axes_active:
    ax.xaxis.set_label_text("Step")
    ax.yaxis.set_label_text("Episodic Return")
    ax.set_xlim(0, 200000)
    ax.set_ylim(0, 1.0)

g.fig.tight_layout(h_pad=1.3, w_pad=1.0)
g.fig.savefig("figures/episodic_returns.pdf", dpi=300)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
from tqdm.auto import tqdm
from expt.plot import GridPlot

plt.clf()
g = GridPlot(y_names=rt.reset_index().env_id.unique())

for env_id, t in tqdm(rt.groupby('env_id')):
    ex = expt.Experiment.from_dataframe(t, name=env_id)
    ex.plot(ax=g[env_id], title=env_id,
            x='global_step', y='charts/cumulative_violations_count',
            err_style='band', std_alpha=0.1,
            rolling=50, n_samples=1000, legend=False,
            tight_layout=False, figsize=(10, 6)
           )

# Put a legend on the last empty grid axes
g.add_legend(ax=g.axes[-1, -1], loc="upper left", bbox_to_anchor=(0, 1))

# Some post-processing with matplotlib API so that the plot looks nicer
for ax in g.axes_active:
    ax.xaxis.set_label_text("Step")
    ax.yaxis.set_label_text("Cumulative number of violations")
    ax.set_xlim(0, 200000)
    ax.set_ylim(0, 4000)

g.fig.tight_layout(h_pad=1.3, w_pad=1.0)
g.fig.savefig("figures/cum_num_violations.pdf", dpi=300)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# !ls runs/MiniGrid-LavaCrossingS9N2-v0__dqn_minigrid_safe_exp__789__1724683463
# Out:
# dqn_minigrid_safe_exp.cleanrl_model			 state_heatmap.npz
# dqn_minigrid_safe_exp_ae.pt				 state_heatmap.svg
# events.out.tfevents.1724683469.ip-10-192-11-240.88342.0

# %%
class StateCountRecorder:
    """Record state distributions, for ploting visitation frequency heatmap"""

    def __init__(self):
        self.shape = (0, 0)
        self.count = np.zeros(self.shape, dtype=np.int32)
        self.rewards = np.zeros(self.shape, dtype=np.float32)
        self.mask = None
        self.lava_mask = None

    def add_count(self, w, h):
        self.count[h, w] += 1

    def add_count_from_env(self, env):
        self.add_count(*env.agent_pos)

    def add_reward(self, w, h, r):
        self.rewards[h, w] += r

    def add_reward_from_env(self, env, reward):
        self.add_reward(*env.agent_pos, reward)

    def get_figure_log_scale(self, cap_threshold_cnt=10_000):
        """ plot heat map visitation, similar to `get_figure` but on log scale"""
        cnt = np.clip(self.count + 1, 0, cap_threshold_cnt)
        plt.clf()
        plt.axis('off')
        # plt.jet()
        plt.imshow(cnt, cmap="jet",
                   norm=matplotlib.colors.LogNorm(vmin=1, vmax=cap_threshold_cnt, clip=True),
                   extent=(0, cnt.shape[1], 0, cnt.shape[0]))
        
        cbar = plt.colorbar()
        cbar.set_label('Visitation counts')
        ax = plt.gca()
        for y in range(cnt.shape[0]):
            for x in range(cnt.shape[1]):
                if self.lava_mask[y][x] == 1:
                    ax.add_patch(Rectangle((x, cnt.shape[0] - 1 - y), 1, 1, fill=False,
                                           edgecolor='red', lw=2))
        
        # over lay walls
        plt.imshow(np.zeros_like(cnt, dtype=np.uint8),
                   cmap="gray", alpha=self.mask.astype(np.float32),
                   extent=(0, cnt.shape[1], 0, cnt.shape[0]),
                   vmin=0, vmax=1)
        return plt.gcf()

    def get_figure(self, cap_threshold_cnt=5000):
        import matplotlib.pyplot as plt
        cnt = np.clip(self.count, 0, cap_threshold_cnt)
        plt.clf()
        plt.jet()
        plt.imshow(cnt, cmap="Blues", vmin=0, vmax=cap_threshold_cnt)
        cbar = plt.colorbar()
        lin_spc = np.linspace(0, cap_threshold_cnt, 6).astype(np.int32)
        # cbar.ax.yaxis.set_major_locator(ticker.FixedLocator(lin_spc))
        cbar.update_ticks()
        lin_spc = [str(i) for i in lin_spc]
        lin_spc[-1] = ">" + lin_spc[-1]
        cbar.ax.set_yticklabels(lin_spc)
        cbar.set_label('Visitation counts')

        # over lay walls
        plt.imshow(np.zeros_like(cnt, dtype=np.uint8),
                   cmap="gray", alpha=self.mask.astype(np.float32),
                   vmin=0, vmax=1)
        return plt.gcf()

    def extract_mask(self, env):
        if self.mask is not None:
            return
        """ Extract walls from grid_env, used for masking wall cells in heatmap """
        self.mask = np.zeros_like(self.count)
        self.lava_mask = np.zeros_like(self.count)
        for i in range(env.grid.height):
            for j in range(env.grid.width):
                c = env.grid.get(i, j)
                if c is not None and c.type == "wall":
                    self.mask[j, i] = 1
                if c is not None and c.type == "lava":
                    self.lava_mask[j, i] = 1

    def save_to(self, file_path):
        np.savez(file_path, count=self.count, wall_mask=self.mask, lava_mask=self.lava_mask)

    def load_from(self, file_path):
        data = np.load(file_path)
        self.count = data['count'].copy()
        self.mask = data['wall_mask'].copy()
        self.lava_mask = data['lava_mask'].copy()
        self.shape = self.count.shape

# %%
import matplotlib
from matplotlib.patches import Rectangle
from mpl_toolkits.axes_grid1 import make_axes_locatable

def load_data(file_path):
    data = np.load(file_path)
    count = data['count'].copy()
    mask = data['wall_mask'].copy()
    lava_mask = data['lava_mask'].copy()
    return count, mask, lava_mask
    
def plot_heatmap(count, mask, lava_mask, ax, cap_threshold_cnt=10000, colorbar=True):
    ax.axis('off')  # Turn off the axes
    cnt = np.clip(count + 1, 0, cap_threshold_cnt)
    # Plot the heatmap
    im = ax.imshow(
        cnt, 
        cmap="jet",
        norm=matplotlib.colors.LogNorm(vmin=1, vmax=cap_threshold_cnt, clip=True),
        aspect='auto',
        extent=(0, cnt.shape[1], 0, cnt.shape[0])
    )
    
    # Create a colorbar
    if colorbar:
        cbar = fig.colorbar(im, ax=ax)
        cbar.set_label('Visitation counts')

    # Overlay rectangles based on lava_mask
    for y in range(cnt.shape[0]):
        for x in range(cnt.shape[1]):
            if lava_mask[y][x] == 1:
                ax.add_patch(Rectangle((x, cnt.shape[0] - 1 - y), 1, 1, fill=False,
                                        edgecolor='red', lw=2))
    
    # Overlay walls
    ax.imshow(
        np.zeros_like(cnt, dtype=np.uint8),
        cmap="gray", 
        aspect='auto',
        alpha=mask.astype(np.float32),
        extent=(0, cnt.shape[1], 0, cnt.shape[0]),
        vmin=0, vmax=1
    )
    return im

# %%
runs = [
    'MiniGrid-LavaCrossingS9N2-v0__dqn_minigrid_per__789__1720955336',
    'MiniGrid-LavaCrossingS9N2-v0__dqn_minigrid_safe__789__1721032088',
    'MiniGrid-LavaCrossingS9N2-v0__dqn_minigrid_safe_exp__789__1724683463'
]
algo_names = {
    'dqn_minigrid_safe_exp': 'DQN + Domain Priors + State Safety Check',
    'dqn_minigrid_per': 'DQN',
    'dqn_minigrid_vae': 'DQN + VAE',
    'dqn_minigrid_ae': 'DQN + Vanilla AE',
    'dqn_minigrid_safe': 'DQN + Domain Priors'
}
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
divider = make_axes_locatable(axes[2])  # Use the last ax to position the colorbar
cax = divider.append_axes("right", size="5%", pad=0.1)  # Adjust size and padding

for i, run in enumerate(runs):
    env_id, algo, seed, timestamp = run.split('__')
    cnt, mask, lava_mask = load_data(f"runs/{run}/state_heatmap.npz")
    im = plot_heatmap(cnt, mask, lava_mask, axes[i], colorbar=False)
    axes[i].set_title(algo_names[algo], fontsize=14)

norm = matplotlib.colors.LogNorm(vmin=1, vmax=10000, clip=True)
cbar = fig.colorbar(im, cax=cax)
cbar.set_label('Visitation counts', fontsize=14)
# cbar.ax.set_yticklabels(['$10^0$', '10^1', '10^2', '10^3', '10^4'])
fig.tight_layout()
fig.savefig('heatmap.pdf', dpi=300)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Sample data for heatmaps
n = 10
data1 = np.random.rand(n, n) * 100
data2 = np.random.rand(n, n) * 100
data3 = np.random.rand(n, n) * 100

# Create a figure and an array of Axes
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Create a common colorbar
divider = make_axes_locatable(axs[2])  # Use the last ax to position the colorbar
cax = divider.append_axes("right", size="5%", pad=0.1)  # Adjust size and padding

# Plot each heatmap
for i, ax in enumerate(axs):
    data = [data1, data2, data3][i]  # Select data for the current heatmap
    im = ax.imshow(data, cmap="jet", norm=matplotlib.colors.LogNorm(vmin=1, vmax=100), aspect='auto')
    ax.set_title(f'Heatmap {i + 1}')  # Title for each heatmap
    ax.axis('off')  # Turn off the axis

# Create the colorbar
cbar = fig.colorbar(im, cax=cax)
cbar.set_label('Common Colorbar Label')

# Adjust layout
plt.tight_layout()
plt.show()
